# %% [markdown]
# <a href="https://colab.research.google.com/github/ambroz72/Data-analytics-/blob/master/Swiggy_data_sentiment_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("swiggydataset.csv")

# %%
df.head()
# Out:
#               date  favorite_count  followers_count  friends_count  \
# 0  7/18/2019 22:47               0               82            219
# 1  7/18/2019 22:43               0              102            129
# 2  7/18/2019 22:37               0              102            129
# 3  7/18/2019 22:35               0               13             16
# 4  7/18/2019 22:25               0              102            129
#
#                                            full_text  retweet_count retweeted  \
# 0  @Mahi_2510 @swiggy_in The ultimate answer will...              0     False
# 1                            @SwiggyCares I hope so.              0     False
# 2  @SwiggyCares I think you have the order detail...              0     False
# 3  @swiggy_in People are complaining here also, i...              0     False
# 4  @SwiggyCares Do you even know the meaning of y...              0     False
#
#      screen_name tweet_id                     user_id
# ...

# %%
df.tail()
# Out:
#                    date  favorite_count  followers_count  friends_count  \
# 16707  07-11-2019 12:13               0                0              2
# 16708  07-11-2019 12:12               0              106            146
# 16709  07-11-2019 12:11               0               91            248
# 16710  07-11-2019 12:11               0                0              2
# 16711  07-11-2019 12:09               0               54            163
#
#                                                full_text  retweet_count  \
# 16707  @SwiggyCares they said as delivery box is not ...              0
# 16708  @swiggy_in Deliver to karta nahi, install kyo ...              0
# 16709  @swiggy_in thanks for spilling my drink. I wai...              0
# 16710  @SwiggyCares hello there i use swigggy regular...              0
# 16711  @Being_Humor @ZomatoIN @swiggy_in can you help...              0
#
#       retweeted      screen_name tweet_id                      user_id
# ...

# %%
df.describe()
# Out:
#        favorite_count  followers_count  friends_count  retweet_count
# count    16712.000000     1.671200e+04   16712.000000   16712.000000
# mean         0.554691     3.156743e+03     384.175383       0.142592
# std          8.973908     9.161054e+04    1652.475629       3.890990
# min          0.000000     0.000000e+00       0.000000       0.000000
# 25%          0.000000     9.000000e+00      48.000000       0.000000
# 50%          0.000000     4.300000e+01     139.000000       0.000000
# 75%          0.000000     1.950000e+02     376.000000       0.000000
# max        916.000000     6.823332e+06  155340.000000     487.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16712 entries, 0 to 16711
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             16712 non-null  object
#  1   favorite_count   16712 non-null  int64
#  2   followers_count  16712 non-null  int64
#  3   friends_count    16712 non-null  int64
#  4   full_text        16712 non-null  object
#  5   retweet_count    16712 non-null  int64
#  6   retweeted        14384 non-null  object
#  7   screen_name      16712 non-null  object
#  8   tweet_id         16712 non-null  object
#  9   user_id          16712 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (16712, 10)

# %%
df.nunique()
# Out:
# date               11097
# favorite_count        52
# followers_count     1524
# friends_count       1505
# full_text          16703
# retweet_count         26
# retweeted              1
# screen_name         8617
# tweet_id           16712
# user_id             8539
# dtype: int64

# %%
df.columns
# Out:
# Index(['date', 'favorite_count', 'followers_count', 'friends_count',
#        'full_text', 'retweet_count', 'retweeted', 'screen_name', 'tweet_id',
#        'user_id'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# date                  0
# favorite_count        0
# followers_count       0
# friends_count         0
# full_text             0
# retweet_count         0
# retweeted          2328
# screen_name           0
# tweet_id              0
# user_id               0
# dtype: int64

# %%
df=df.fillna(0)

# %%
df.isnull().sum()
# Out:
# date               0
# favorite_count     0
# followers_count    0
# friends_count      0
# full_text          0
# retweet_count      0
# retweeted          0
# screen_name        0
# tweet_id           0
# user_id            0
# dtype: int64

# %%
df.nunique()
# Out:
# date               11097
# favorite_count        52
# followers_count     1524
# friends_count       1505
# full_text          16703
# retweet_count         26
# retweeted              1
# screen_name         8617
# tweet_id           16712
# user_id             8539
# dtype: int64

# %%
df.notnull().sum()
# Out:
# date               16712
# favorite_count     16712
# followers_count    16712
# friends_count      16712
# full_text          16712
# retweet_count      16712
# retweeted          16712
# screen_name        16712
# tweet_id           16712
# user_id            16712
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, favorite_count, followers_count, friends_count, full_text, retweet_count, retweeted, screen_name, tweet_id, user_id]
# Index: []

# %%
# Convert date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
# Convert retweeted to boolean
df['retweeted'] = df['retweeted'].astype(str).str.lower().map({'true': True, 'false': False})

# %%
# Clean user_id (remove commas)
df['user_id'] = df['user_id'].astype(str).str.replace(",", "").astype('int64', errors='ignore')

# %%
print(df.head())
# Out:
#                  date  favorite_count  followers_count  friends_count  \
# 0 2019-07-18 22:47:00               0               82            219
# 1 2019-07-18 22:43:00               0              102            129
# 2 2019-07-18 22:37:00               0              102            129
# 3 2019-07-18 22:35:00               0               13             16
# 4 2019-07-18 22:25:00               0              102            129
#
#                                            full_text  retweet_count retweeted  \
# 0  @Mahi_2510 @swiggy_in The ultimate answer will...              0     False
# 1                            @SwiggyCares I hope so.              0     False
# 2  @SwiggyCares I think you have the order detail...              0     False
# 3  @swiggy_in People are complaining here also, i...              0     False
# 4  @SwiggyCares Do you even know the meaning of y...              0     False
#
#      screen_name tweet_id             user_id
# ...

# %%
# Tweets per user
top_users = df['screen_name'].value_counts().head(10)
print("Top 10 active users:\n", top_users)
# Out:
# Top 10 active users:
#  screen_name
# SandipThink        71
# SwiggyCares        70
# Vineeta75481990    53
# bachPunn           53
# zomatocare         45
# RohitKu49925795    42
# peeceeliciouss     39
# chat_sayan         35
# Raghupa33220091    35
# i_Am_aware_of      29
# Name: count, dtype: int64

# %%
import  matplotlib.pyplot as plt

# %%
# Tweets per day
tweets_per_day = df.groupby(df['date'].dt.date).size()
tweets_per_day.plot(kind='line', figsize=(18,8), title="Tweets per Day")
plt.show()

# %%
# Engagement stats
avg_likes = df['favorite_count'].mean()
avg_retweets = df['retweet_count'].mean()
print(f"Average Likes: {avg_likes:.2f}, Average Retweets: {avg_retweets:.2f}")
# Out:
# Average Likes: 0.55, Average Retweets: 0.14

# %%
import seaborn as sns

# %%
# Correlation between followers and engagement
sns.scatterplot(x='followers_count', y='favorite_count', data=df, alpha=0.5)
plt.title("Followers vs Likes")
plt.show()

# %%
from wordcloud import WordCloud
from textblob import TextBlob

# %%
# Word Cloud
text = " ".join(df['full_text'].dropna().astype(str).tolist())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Sentiment Analysis
def get_sentiment(text):
    return TextBlob(str(text)).sentiment.polarity

df['sentiment'] = df['full_text'].apply(get_sentiment)
sns.histplot(df['sentiment'], bins=30, kde=True)
plt.title("Sentiment Distribution")
plt.show()

# %%
print(df[['full_text', 'sentiment']].head())
# Out:
#                                            full_text  sentiment
# 0  @Mahi_2510 @swiggy_in The ultimate answer will...  -0.250000
# 1                            @SwiggyCares I hope so.   0.000000
# 2  @SwiggyCares I think you have the order detail...   0.142857
# 3  @swiggy_in People are complaining here also, i...   0.010417
# 4  @SwiggyCares Do you even know the meaning of y...   0.000000

# %%
# 6. Retweet Insights
# ===============================
retweet_stats = df.groupby('retweeted').size()
print("Tweets vs Retweets:\n", retweet_stats)
# Out:
# Tweets vs Retweets:
#  retweeted
# False    14384
# dtype: int64

# %%
top_retweets = df.sort_values('retweet_count', ascending=False).head(5)
print("Most retweeted posts:\n", top_retweets[['screen_name', 'full_text', 'retweet_count']])
# Out:
# Most retweeted posts:
#            screen_name                                          full_text  \
# 9258   Ibleed_sarcasm  .@SwiggyCares \n Pic 1: when customer is Guy\n...
# 5124         DhooDala  I craved for an Ice Creame this scorching afte...
# 1176    RoadsOfMumbai  #ShameOnSwiggy!\n \n @swiggy_in delivery agent...
# 10721    TOIBengaluru  Co-Founder &amp; CTO of Indiaâ€™s fastest Unic...
# 11476    SudhirKumar3  @SwiggyCares @PMCPune @CMOMaharashtra @MountNG...
#
#        retweet_count
# 9258             487
# 5124              64
# 1176              37
# 10721             34
# 11476             29
