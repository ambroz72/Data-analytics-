# %% [markdown]
# <a href="https://colab.research.google.com/github/ambroz72/Data-analytics-/blob/master/Sales_Performance_Analysis2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset

# %%
data=pd.read_excel('company_data.xlsx')

# %%
data.head()
# Out:
#    Order ID  Order Date   Unit Cost   Price  Order Qty  Cost of Sales  \
# 0      7077       42991   76.094968  304.00          9     684.854710
# 1       117       42602    7.491753   12.99          4      29.967011
# 2      7018       42559   10.122338  159.99          9      91.101039
# 3       140       43323    0.576153   25.69         18      10.370759
# 4       491       42931  108.508777  304.00          9     976.578991
#
#        Sales       Profit Channel                  Promotion Name  \
# 0  2714.7200  2029.865290   Store       European Spring Promotion
# 1    50.1414    20.174389   Store       European Spring Promotion
# 2  1395.1128  1304.011761   Store       European Spring Promotion
# 3   462.4200   452.049241   Store  North America Spring Promotion
# 4  2614.4000  1637.821009  Online          Asian Spring Promotion
#
#                                      Product Name       Manufacturer  \
# 0                    Contoso SLR Camera M143 Grey       Contoso, Ltd
# 1               Contoso 512MB MP3 Player E51 Blue       Contoso, Ltd
# 2  Contoso DVD 9-Inch Player Portable M300 Silver       Contoso, Ltd
# 3         NT Bluetooth Stereo Headphones E52 Pink  Northwind Traders
# 4                    Contoso SLR Camera M143 Grey       Contoso, Ltd
#
#    Product Sub Category               Product Category         Region  \
# 0   Digital SLR Cameras        Cameras and camcorders          Europe
# 1               MP4&MP3                          Audio         Europe
# 2             Movie DVD  Music, Movies and Audio Books         Europe
# 3  Bluetooth Headphones                          Audio  North America
# 4   Digital SLR Cameras        Cameras and camcorders            Asia
#
#        City        Country
# 0    Moscow         Russia
# 1    Moscow         Russia
# 2    Moscow         Russia
# 3  Bellevue  United States
# 4   Beijing          China

# %%
data.tail()
# Out:
#        Order ID  Order Date   Unit Cost  Price  Order Qty  Cost of Sales  \
# 14995     22348       42646   16.240455   25.0         12     194.885455
# 14996     22349       42663   55.387212  999.0         10     553.872121
# 14997     22350       42875  363.634986  588.0         13    4727.254816
# 14998     22351       43044  113.237461  279.0         12    1358.849536
# 14999     22352       43344   10.936943   15.9         20     218.738862
#
#         Sales       Profit   Channel                   Promotion Name  \
# 14995   300.0   105.114545     Store           Asian Summer Promotion
# 14996  9990.0  9436.127879  Reseller                      No Discount
# 14997  7408.8  2681.545184     Store  North America Holiday Promotion
# 14998  3348.0  1989.150464    Online           Asian Summer Promotion
# 14999   318.0    99.261138     Store                      No Discount
#
#                                            Product Name          Manufacturer  \
# 14995                       Contoso USB Cable M250 Blue          Contoso, Ltd
# 14996                    WWI Projector 720p DLP56 White  Wide World Importers
# 14997                 A. Datum SLR Camera 35" X358 Gold  A. Datum Corporation
# 14998                 Adventure Works LCD20W M240 Black       Adventure Works
# 14999  Contoso USB Wave Multi-media Keyboard E280 Black          Contoso, Ltd
#
#                    Product Sub Category         Product Category  \
# 14995  Cameras & Camcorders Accessories  Cameras and camcorders
# 14996              Projectors & Screens                Computers
# 14997               Digital SLR Cameras  Cameras and camcorders
# 14998                          Monitors                Computers
# 14999             Computers Accessories                Computers
#
#               Region     City        Country
# 14995           Asia    Osaka          Japan
# 14996         Europe    Paris         France
# 14997  North America   Ithaca  United States
# 14998           Asia  Beijing          China
# 14999  North America   Spring  United States

# %%
data.shape
# Out:
# (15000, 17)

# %%
data.nunique()
# Out:
# Order ID                15000
# Order Date               1096
# Unit Cost               15000
# Price                     350
# Order Qty                  52
# Cost of Sales           15000
# Sales                    6875
# Profit                  15000
# Channel                     4
# Promotion Name             10
# Product Name             1638
# Manufacturer               10
# Product Sub Category       22
# Product Category            6
# Region                      3
# City                      263
# Country                    34
# dtype: int64

# %%
data.columns
# Out:
# Index(['Order ID', 'Order Date', 'Unit Cost', 'Price', 'Order Qty',
#        'Cost of Sales', 'Sales', 'Profit', 'Channel', 'Promotion Name',
#        'Product Name', 'Manufacturer', 'Product Sub Category',
#        'Product Category', 'Region', 'City', 'Country'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Order ID                  int64
# Order Date                int64
# Unit Cost               float64
# Price                   float64
# Order Qty                 int64
# Cost of Sales           float64
# Sales                   float64
# Profit                  float64
# Channel                  object
# Promotion Name           object
# Product Name             object
# Manufacturer             object
# Product Sub Category     object
# Product Category         object
# Region                   object
# City                     object
# Country                  object
# dtype: object

# %%
data.describe()
# Out:
#            Order ID    Order Date     Unit Cost         Price     Order Qty  \
# count  15000.000000  15000.000000  15000.000000  15000.000000  15000.000000
# mean   11209.316600  43007.083600    124.425132    296.514697     16.741733
# std     6451.583877    316.044076    163.569912    345.985232     43.490032
# min        1.000000  42523.000000      0.001576      0.950000      4.000000
# 25%     5629.750000  42728.000000     16.847345     59.000000      9.000000
# 50%    11238.500000  42964.000000     69.688876    205.000000     10.000000
# 75%    16789.500000  43269.000000    164.348636    366.000000     13.000000
# max    22352.000000  43618.000000   1896.133845   2899.990000   1560.000000
#
#        Cost of Sales         Sales        Profit
# count   15000.000000  15000.000000  15000.000000
# mean     1586.954833   3692.783986   2105.829152
# std      2408.961430   4917.886955   3387.145437
# min         0.015756      4.750000   -838.426733
# 25%       189.677420    645.000000    242.198732
# 50%       752.752320   2301.175750   1012.683637
# 75%      2006.030237   4767.720000   2573.128436
# max     42991.137192  78312.000000  55692.569522

# %%
# Data cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Order ID              15000 non-null  int64
#  1   Order Date            15000 non-null  int64
#  2   Unit Cost             15000 non-null  float64
#  3   Price                 15000 non-null  float64
#  4   Order Qty             15000 non-null  int64
#  5   Cost of Sales         15000 non-null  float64
#  6   Sales                 15000 non-null  float64
#  7   Profit                15000 non-null  float64
#  8   Channel               15000 non-null  object
#  9   Promotion Name        15000 non-null  object
#  10  Product Name          15000 non-null  object
#  11  Manufacturer          15000 non-null  object
#  12  Product Sub Category  15000 non-null  object
#  13  Product Category      15000 non-null  object
#  14  Region                15000 non-null  object
#  15  City                  15000 non-null  object
#  16  Country               15000 non-null  object
# dtypes: float64(5), int64(3), object(9)
# memory usage: 1.9+ MB

# %%
data.isnull().sum()
# Out:
# Order ID                0
# Order Date              0
# Unit Cost               0
# Price                   0
# Order Qty               0
# Cost of Sales           0
# Sales                   0
# Profit                  0
# Channel                 0
# Promotion Name          0
# Product Name            0
# Manufacturer            0
# Product Sub Category    0
# Product Category        0
# Region                  0
# City                    0
# Country                 0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Order ID                15000
# Order Date              15000
# Unit Cost               15000
# Price                   15000
# Order Qty               15000
# Cost of Sales           15000
# Sales                   15000
# Profit                  15000
# Channel                 15000
# Promotion Name          15000
# Product Name            15000
# Manufacturer            15000
# Product Sub Category    15000
# Product Category        15000
# Region                  15000
# City                    15000
# Country                 15000
# dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Unit Cost, Price, Order Qty, Cost of Sales, Sales, Profit, Channel, Promotion Name, Product Name, Manufacturer, Product Sub Category, Product Category, Region, City, Country]
# Index: []

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
data
# Out:
#        Order ID                    Order Date   Unit Cost   Price  Order Qty  \
# 0          7077 1970-01-01 00:00:00.000042991   76.094968  304.00          9
# 1           117 1970-01-01 00:00:00.000042602    7.491753   12.99          4
# 2          7018 1970-01-01 00:00:00.000042559   10.122338  159.99          9
# 3           140 1970-01-01 00:00:00.000043323    0.576153   25.69         18
# 4           491 1970-01-01 00:00:00.000042931  108.508777  304.00          9
# ...         ...                           ...         ...     ...        ...
# 14995     22348 1970-01-01 00:00:00.000042646   16.240455   25.00         12
# 14996     22349 1970-01-01 00:00:00.000042663   55.387212  999.00         10
# 14997     22350 1970-01-01 00:00:00.000042875  363.634986  588.00         13
# 14998     22351 1970-01-01 00:00:00.000043044  113.237461  279.00         12
# 14999     22352 1970-01-01 00:00:00.000043344   10.936943   15.90         20
#
#        Cost of Sales      Sales       Profit   Channel  \
# 0         684.854710  2714.7200  2029.865290     Store
# 1          29.967011    50.1414    20.174389     Store
# 2          91.101039  1395.1128  1304.011761     Store
# 3          10.370759   462.4200   452.049241     Store
# 4         976.578991  2614.4000  1637.821009    Online
# ...              ...        ...          ...       ...
# 14995     194.885455   300.0000   105.114545     Store
# 14996     553.872121  9990.0000  9436.127879  Reseller
# 14997    4727.254816  7408.8000  2681.545184     Store
# 14998    1358.849536  3348.0000  1989.150464    Online
# 14999     218.738862   318.0000    99.261138     Store
#
#                         Promotion Name  \
# 0            European Spring Promotion
# 1            European Spring Promotion
# 2            European Spring Promotion
# 3       North America Spring Promotion
# 4               Asian Spring Promotion
# ...                                ...
# 14995           Asian Summer Promotion
# 14996                      No Discount
# 14997  North America Holiday Promotion
# 14998           Asian Summer Promotion
# 14999                      No Discount
#
#                                            Product Name          Manufacturer  \
# 0                          Contoso SLR Camera M143 Grey          Contoso, Ltd
# 1                     Contoso 512MB MP3 Player E51 Blue          Contoso, Ltd
# 2        Contoso DVD 9-Inch Player Portable M300 Silver          Contoso, Ltd
# 3               NT Bluetooth Stereo Headphones E52 Pink     Northwind Traders
# 4                          Contoso SLR Camera M143 Grey          Contoso, Ltd
# ...                                                 ...                   ...
# 14995                       Contoso USB Cable M250 Blue          Contoso, Ltd
# 14996                    WWI Projector 720p DLP56 White  Wide World Importers
# 14997                 A. Datum SLR Camera 35" X358 Gold  A. Datum Corporation
# 14998                 Adventure Works LCD20W M240 Black       Adventure Works
# 14999  Contoso USB Wave Multi-media Keyboard E280 Black          Contoso, Ltd
#
#                    Product Sub Category               Product Category  \
# 0                   Digital SLR Cameras        Cameras and camcorders
# 1                               MP4&MP3                          Audio
# 2                             Movie DVD  Music, Movies and Audio Books
# 3                  Bluetooth Headphones                          Audio
# 4                   Digital SLR Cameras        Cameras and camcorders
# ...                                 ...                            ...
# 14995  Cameras & Camcorders Accessories        Cameras and camcorders
# 14996              Projectors & Screens                      Computers
# 14997               Digital SLR Cameras        Cameras and camcorders
# 14998                          Monitors                      Computers
# 14999             Computers Accessories                      Computers
#
#               Region      City        Country
# 0             Europe    Moscow         Russia
# 1             Europe    Moscow         Russia
# 2             Europe    Moscow         Russia
# 3      North America  Bellevue  United States
# 4               Asia   Beijing          China
# ...              ...       ...            ...
# 14995           Asia     Osaka          Japan
# 14996         Europe     Paris         France
# 14997  North America    Ithaca  United States
# 14998           Asia   Beijing          China
# 14999  North America    Spring  United States
#
# [15000 rows x 17 columns]

# %%
# Optional: Convert 'Date' column to datetime
data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=data['Sales'])
plt.title('Boxplot of Sales')
plt.show()

# %%
# Create additional useful columns
data['Month'] = data['Order Date'].dt.month
data['Year'] = data['Order Date'].dt.year
data['Month_Year'] = data['Order Date'].dt.to_period('M')

# %%
data
# Out:
#        Order ID                    Order Date   Unit Cost   Price  Order Qty  \
# 0          7077 1970-01-01 00:00:00.000042991   76.094968  304.00          9
# 1           117 1970-01-01 00:00:00.000042602    7.491753   12.99          4
# 2          7018 1970-01-01 00:00:00.000042559   10.122338  159.99          9
# 3           140 1970-01-01 00:00:00.000043323    0.576153   25.69         18
# 4           491 1970-01-01 00:00:00.000042931  108.508777  304.00          9
# ...         ...                           ...         ...     ...        ...
# 14995     22348 1970-01-01 00:00:00.000042646   16.240455   25.00         12
# 14996     22349 1970-01-01 00:00:00.000042663   55.387212  999.00         10
# 14997     22350 1970-01-01 00:00:00.000042875  363.634986  588.00         13
# 14998     22351 1970-01-01 00:00:00.000043044  113.237461  279.00         12
# 14999     22352 1970-01-01 00:00:00.000043344   10.936943   15.90         20
#
#        Cost of Sales      Sales       Profit   Channel  \
# 0         684.854710  2714.7200  2029.865290     Store
# 1          29.967011    50.1414    20.174389     Store
# 2          91.101039  1395.1128  1304.011761     Store
# 3          10.370759   462.4200   452.049241     Store
# 4         976.578991  2614.4000  1637.821009    Online
# ...              ...        ...          ...       ...
# 14995     194.885455   300.0000   105.114545     Store
# 14996     553.872121  9990.0000  9436.127879  Reseller
# 14997    4727.254816  7408.8000  2681.545184     Store
# 14998    1358.849536  3348.0000  1989.150464    Online
# 14999     218.738862   318.0000    99.261138     Store
#
#                         Promotion Name  \
# 0            European Spring Promotion
# 1            European Spring Promotion
# 2            European Spring Promotion
# 3       North America Spring Promotion
# 4               Asian Spring Promotion
# ...                                ...
# 14995           Asian Summer Promotion
# 14996                      No Discount
# 14997  North America Holiday Promotion
# 14998           Asian Summer Promotion
# 14999                      No Discount
#
#                                            Product Name          Manufacturer  \
# 0                          Contoso SLR Camera M143 Grey          Contoso, Ltd
# 1                     Contoso 512MB MP3 Player E51 Blue          Contoso, Ltd
# 2        Contoso DVD 9-Inch Player Portable M300 Silver          Contoso, Ltd
# 3               NT Bluetooth Stereo Headphones E52 Pink     Northwind Traders
# 4                          Contoso SLR Camera M143 Grey          Contoso, Ltd
# ...                                                 ...                   ...
# 14995                       Contoso USB Cable M250 Blue          Contoso, Ltd
# 14996                    WWI Projector 720p DLP56 White  Wide World Importers
# 14997                 A. Datum SLR Camera 35" X358 Gold  A. Datum Corporation
# 14998                 Adventure Works LCD20W M240 Black       Adventure Works
# 14999  Contoso USB Wave Multi-media Keyboard E280 Black          Contoso, Ltd
#
#                    Product Sub Category               Product Category  \
# 0                   Digital SLR Cameras        Cameras and camcorders
# 1                               MP4&MP3                          Audio
# 2                             Movie DVD  Music, Movies and Audio Books
# 3                  Bluetooth Headphones                          Audio
# 4                   Digital SLR Cameras        Cameras and camcorders
# ...                                 ...                            ...
# 14995  Cameras & Camcorders Accessories        Cameras and camcorders
# 14996              Projectors & Screens                      Computers
# 14997               Digital SLR Cameras        Cameras and camcorders
# 14998                          Monitors                      Computers
# 14999             Computers Accessories                      Computers
#
#               Region      City        Country  Month  Year Month_Year
# 0             Europe    Moscow         Russia      1  1970    1970-01
# 1             Europe    Moscow         Russia      1  1970    1970-01
# 2             Europe    Moscow         Russia      1  1970    1970-01
# 3      North America  Bellevue  United States      1  1970    1970-01
# 4               Asia   Beijing          China      1  1970    1970-01
# ...              ...       ...            ...    ...   ...        ...
# 14995           Asia     Osaka          Japan      1  1970    1970-01
# 14996         Europe     Paris         France      1  1970    1970-01
# 14997  North America    Ithaca  United States      1  1970    1970-01
# 14998           Asia   Beijing          China      1  1970    1970-01
# 14999  North America    Spring  United States      1  1970    1970-01
#
# [15000 rows x 20 columns]

# %%
# First, make sure 'Order Date' is numeric
data['Order Date'] = pd.to_numeric(data['Order Date'], errors='coerce')

# %%
# Convert serial numbers to datetime
data['Order Date'] = pd.to_datetime('1899-12-30') + pd.to_timedelta(data['Order Date'], unit='D')

# %%
# Create extra columns for time-based analysis

# Create extra date-related columns for analysis
data['Month'] = data['Order Date'].dt.month
data['Year'] = data['Order Date'].dt.year
data['Month_Year'] = data['Order Date'].dt.to_period('M')

data[['Order Date', 'Month', 'Year', 'Month_Year']].head()
# Out:
#   Order Date  Month  Year Month_Year
# 0 2017-09-13      9  2017    2017-09
# 1 2016-08-20      8  2016    2016-08
# 2 2016-07-08      7  2016    2016-07
# 3 2018-08-11      8  2018    2018-08
# 4 2017-07-15      7  2017    2017-07

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data['Sales'], bins=30, kde=True)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Year')
plt.show()

# %%
# sales Trend Over Time

# %%
monthly_sales = data.groupby(data['Order Date'].dt.to_period('M'))['Sales'].sum()
monthly_sales.plot(kind='line', figsize=(12, 6))
plt.title('Sales Trend Over Time')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.show()

# %%
# Peak sales Season

# %%
sns.scatterplot(data=data, x='Order Qty', y='Sales')
plt.title('order quantity vs sales')
plt.show()

# %%
# Total revenue by month
monthly = data.groupby('Month')['Cost of Sales'].sum()
sns.barplot(x=monthly.index, y=monthly.values)
plt.title('Cost of Sales by Month (Peak Season)')
plt.xlabel('Month')
plt.ylabel('Cost of Sales')
plt.show()

# %%
# Top Products by Sales

# %%
# Top 10 products by revenue
top_products = data.groupby('Product Name')['Cost of Sales'].sum().sort_values(ascending=False).head(10)
top_products.plot(kind='bar', figsize=(10,5), title='Top 10 Products by Revenue')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# Sales by Regional or Channel Analysis (Optional if you have region/channel)

# %%
# Example: Sales by Region
region_sales = data.groupby('Region')['Sales'].sum()
region_sales.plot(kind='bar', title='Sales by Region')
plt.ylabel('Revenue')
plt.show()

# %%
summary = data.groupby('Product Name').agg({'Order Qty':'sum', 'Sales':'sum'}).sort_values(by='Sales', ascending=False)
summary.head(10)
# Out:
#                                                   Order Qty       Sales
# Product Name
# Contoso Projector 1080p X980 Black                      197  445115.250
# Proseware Projector 1080p LCD86 White                   186  417575.250
# Contoso Projector 1080p X980 White                      177  399903.750
# Proseware Projector 1080p LCD86 Black                   160  360567.450
# Proseware Projector 1080p DLP86 Silver                  147  358806.420
# Proseware Projector 1080p DLP86 Black                   131  321871.200
# Adventure Works Desktop PC1.80 ED182 White              580  288272.334
# Fabrikam Independent Filmmaker 1" 25mm X400 Blue        173  275157.000
# WWI Laptop19W X0196 Blue                                209  266359.950
# Proseware Projector 1080p DLP86 White                    92  228033.750

# %%
# Save as CSV (Tableau supports CSV well)
data.to_csv("cleaned_sales_data.csv", index=False)

# %%
from google.colab import files
files.download("cleaned_sales_data.csv")
