# %%
import pandas as pd

# %%
sales=pd.read_csv('sales.csv')

# %%
sales
# Out:
#      Invoice ID  Date   Time  Gender     Location     City Member   Category  \
# 0     460489604     1  16:46    Male   Brookfield  NewYork    Yes  Groceries
# 1     471006167     1  16:48  Female  Water tower  Chicago    Yes    Fashion
# 2     411909258     1  13:33    Male  Water tower  Chicago     No   Clothing
# 3     487313402     1  13:38  Female    Park lane   Dallas    Yes   Sporting
# 4     197763430     1  15:31  Female    Park lane   Dallas     No      Books
# ..          ...   ...    ...     ...          ...      ...    ...        ...
# 995   818829599     1  11:19    Male    Park lane   Dallas     No  Groceries
# 996   556589713     1  17:17    Male  Water tower  Chicago    Yes  Groceries
# 997    82324424     1  11:44    Male   Brookfield  NewYork     No   Clothing
# 998   783661702     1  15:44  Female   Brookfield  NewYork     No   Clothing
# 999   759171975     1  10:13  Female  Water tower  Chicago    Yes   Clothing
#
#      Price  Quantity  Total Payment  Rating  Day
# 0       30         1     30    Cash       2    1
# 1       35         5    175    Card       3    1
# 2       57         2    114    Cash       5    1
# 3       89         4    356    Gpay       1    1
# 4       82         5    410    Cash       4    1
# ..     ...       ...    ...     ...     ...  ...
# 995     31         4    124    Card       3    1
# 996      3         5     15    Gpay       3    1
# 997     71         5    355    Card       3    1
# 998     89         7    623    Cash       5    1
# 999     31         7    217    Gpay       3    1
#
# [1000 rows x 14 columns]

# %%
 sales.head(10)
# Out:
#    Invoice ID  Date   Time  Gender     Location     City Member   Category  \
# 0   460489604     1  16:46    Male   Brookfield  NewYork    Yes  Groceries
# 1   471006167     1  16:48  Female  Water tower  Chicago    Yes    Fashion
# 2   411909258     1  13:33    Male  Water tower  Chicago     No   Clothing
# 3   487313402     1  13:38  Female    Park lane   Dallas    Yes   Sporting
# 4   197763430     1  15:31  Female    Park lane   Dallas     No      Books
# 5   263634050     1  17:55    Male   Brookfield  NewYork    Yes   Clothing
# 6    99646662     1  13:21    Male  Water tower  Chicago     No   Clothing
# 7   188869875     1  13:24    Male    Park lane   Dallas     No      Books
# 8   325637547     1  15:33    Male    Park lane   Dallas    Yes   Clothing
# 9   562942936     1  16:05  Female    Park lane   Dallas     No      Books
#
#    Price  Quantity  Total Payment  Rating  Day
# 0     30         1     30    Cash       2    1
# 1     35         5    175    Card       3    1
# 2     57         2    114    Cash       5    1
# 3     89         4    356    Gpay       1    1
# 4     82         5    410    Cash       4    1
# 5     52         4    208    Gpay       3    1
# 6     81         3    243    Cash       4    1
# 7     80         2    160    Cash       3    1
# 8     91         3    273    Card       3    1
# 9     80         2    160    Cash       4    1

# %%
sales['Invoice ID']
# Out:
# 0      460489604
# 1      471006167
# 2      411909258
# 3      487313402
# 4      197763430
#          ...
# 995    818829599
# 996    556589713
# 997     82324424
# 998    783661702
# 999    759171975
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
sales[200:210]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35    Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07    Male  Water tower  Chicago     No
# 202   123247697   2/8/2018  20:03    Male   Brookfield  NewYork     No
# 203    40419058  1/26/2018  14:53    Male  Water tower  Chicago    Yes
# 204   890497298  2/25/2018  18:06  Female  Water tower  Chicago     No
# 205   885702268  1/28/2018  12:45    Male   Brookfield  NewYork     No
# 206   172252194  3/22/2018  20:10  Female    Park lane   Dallas     No
# 207   866140211  2/25/2018  13:34  Female    Park lane   Dallas     No
# 208   597678548  3/15/2018  17:35    Male  Water tower  Chicago    Yes
# 209   428818456  2/25/2018  18:50    Male    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card       4
# 201   Sporting     44         7    308    Card       3
# 202  Groceries     22         7    154    Card       5
# 203      Books     95         6    570    Card       1
# 204   Clothing     69         2    138    Cash       2
# 205  Groceries     89         6    534    Card       1
# 206      Books     41         6    246    Card       4
# 207   Clothing     54         6    324    Gpay       4
# 208   Sporting     34         3    102    Cash       1
# 209      Books     94         5    470    Cash       2

# %%
sales.tail()
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 995  Groceries     31         4    124    Card       3
# 996  Groceries      3         5     15    Gpay       3
# 997   Clothing     71         5    355    Card       3
# 998   Clothing     89         7    623    Cash       5
# 999   Clothing     31         7    217    Gpay       3

# %%
sales[sales['Gender']=='Male']
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# 2     Clothing     57         2    114    Cash       5
# 5     Clothing     52         4    208    Gpay       3
# 6     Clothing     81         3    243    Cash       4
# 7        Books     80         2    160    Cash       3
# ..         ...    ...       ...    ...     ...     ...
# 992      Books     54         1     54    Card       1
# 994    Fashion     29         5    145    Cash       4
# 995  Groceries     31         4    124    Card       3
# 996  Groceries      3         5     15    Gpay       3
# 997   Clothing     71         5    355    Card       3
#
# [499 rows x 13 columns]

# %%
sales[sales['Total']>100]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# 2     Clothing     57         2    114    Cash       5
# 3     Sporting     89         4    356    Gpay       1
# 4        Books     82         5    410    Cash       4
# 5     Clothing     52         4    208    Gpay       3
# ..         ...    ...       ...    ...     ...     ...
# 994    Fashion     29         5    145    Cash       4
# 995  Groceries     31         4    124    Card       3
# 997   Clothing     71         5    355    Card       3
# 998   Clothing     89         7    623    Cash       5
# 999   Clothing     31         7    217    Gpay       3
#
# [658 rows x 13 columns]

# %%
sales[sales['Payment']=='Cash']
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# 2     Clothing     57         2    114    Cash       5
# 4        Books     82         5    410    Cash       4
# 6     Clothing     81         3    243    Cash       4
# 7        Books     80         2    160    Cash       3
# ..         ...    ...       ...    ...     ...     ...
# 989   Sporting     19         7    133    Cash       1
# 990   Clothing     25         4    100    Cash       5
# 993   Clothing      3         3      9    Cash       2
# 994    Fashion     29         5    145    Cash       4
# 998   Clothing     89         7    623    Cash       5
#
# [344 rows x 13 columns]

# %%
u = sales['Category'].drop_duplicates()
print(u)
# Out:
# 0     Groceries
# 1       Fashion
# 2      Clothing
# 3      Sporting
# 4         Books
# 10    Furniture
# Name: Category, dtype: object

# %%
sales.sum()['Total']
# Out:
# 207788

# %%
sales.sum()['Quantity']
# Out:
# 4059

# %%
sales.max()
# Out:
# Invoice ID      999665753
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
sales[sales['Total']>100].head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
#
#    Category  Price  Quantity  Total Payment  Rating
# 1   Fashion     35         5    175    Card       3
# 2  Clothing     57         2    114    Cash       5
# 3  Sporting     89         4    356    Gpay       1
# 4     Books     82         5    410    Cash       4
# 5  Clothing     52         4    208    Gpay       3

# %%
sales[sales['Total']==sales.max()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales['Total']
# Out:
# 0       30
# 1      175
# 2      114
# 3      356
# 4      410
#       ...
# 995    124
# 996     15
# 997    355
# 998    623
# 999    217
# Name: Total, Length: 1000, dtype: int64

# %%
 sales['Total'].min()
# Out:
# 1

# %%
sales['Total'].max()
# Out:
# 693

# %%
sales['Total'].mean()
# Out:
# 207.788

# %%
sales.groupby('City').sum()
# Out:
#            Invoice ID                                               Date  \
# City
# Chicago  164244758326  3/19/20182/25/20183/4/20181/18/20183/7/20183/2...
# Dallas   160721744770  1/22/20182/18/20183/8/20181/18/20182/24/20183/...
# NewYork  169526550245  1/25/20183/9/20182/26/20183/21/20182/15/20182/...
#
#                                                       Time  \
# City
# Chicago  16:4813:3313:2115:2012:5010:1115:0211:5715:571...
# Dallas   13:3815:3113:2415:3316:0512:1211:1218:1816:081...
# NewYork  16:4617:5511:3213:2315:4715:5910:5819:4819:311...
#
#                                                     Gender  \
# City
# Chicago  FemaleMaleMaleFemaleMaleMaleMaleMaleMaleFemale...
# Dallas   FemaleFemaleMaleMaleFemaleMaleMaleMaleFemaleFe...
# NewYork  MaleMaleFemaleFemaleFemaleFemaleFemaleFemaleFe...
#
#                                                   Location  \
# City
# Chicago  Water towerWater towerWater towerWater towerWa...
# Dallas   Park lanePark lanePark lanePark lanePark laneP...
# NewYork  BrookfieldBrookfieldBrookfieldBrookfieldBrookf...
#
#                                                     Member  \
# City
# Chicago  YesNoNoYesNoYesNoNoYesYesNoNoNoYesYesNoNoNoNoN...
# Dallas   YesNoNoYesNoNoNoYesNoNoYesYesNoNoYesNoYesYesYe...
# NewYork  YesYesNoNoYesYesYesNoNoYesYesNoNoNoNoYesYesNoY...
#
#                                                   Category  Price  Quantity  \
# City
# Chicago  FashionClothingClothingClothingGroceriesGrocer...  16152      1307
# Dallas   SportingBooksBooksClothingBooksSportingClothin...  17289      1344
# NewYork  GroceriesClothingFurnitureFashionClothingSport...  17671      1408
#
#          Total                                            Payment  Rating
# City
# Chicago  65215  CardCashCashGpayCashGpayGpayCardGpayGpayCashGp...    1023
# Dallas   70432  GpayCashCashCardCashCardCashCashGpayCashCardCa...    1003
# NewYork  72141  CashGpayGpayGpayCardGpayGpayCashCardCardCardCa...     946

# %%
sales.groupby('City').sum()['Total']
# Out:
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sales.groupby('Date').sum()['Total']
# Out:
# Date
# 1/1/2018     2649
# 1/10/2018    1116
# 1/11/2018    1562
# 1/12/2018    2625
# 1/13/2018    2340
#              ...
# 3/5/2018     4616
# 3/6/2018     1915
# 3/7/2018     1048
# 3/8/2018     2638
# 3/9/2018     4300
# Name: Total, Length: 89, dtype: int64

# %%
sales.groupby('Category').sum()['Total']
# Out:
# Category
# Books        36103
# Clothing     35925
# Fashion      32778
# Furniture    34141
# Groceries    31236
# Sporting     37605
# Name: Total, dtype: int64

# %%
sales.groupby('Member').sum()['Total']
# Out:
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
sales.groupby('Gender').sum()['Total']
# Out:
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
sales.groupby('Payment').sum()['Total']
# Out:
# Payment
# Card    64264
# Cash    72643
# Gpay    70881
# Name: Total, dtype: int64

# %%
  sales.groupby(['Gender','Payment']).sum()['Total']
# Out:
# Gender  Payment
# Female  Card       31137
#         Cash       35298
#         Gpay       40017
# Male    Card       33127
#         Cash       37345
#         Gpay       30864
# Name: Total, dtype: int64

# %%
s = sales[(sales['Total'] > 100) & (sales['Total'] < 200)]
print(s)
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9     562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 977   614557665  3/22/2018  17:16  Female    Park lane   Dallas     No
# 981   418253101  3/14/2018  12:25  Female   Brookfield  NewYork     No
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# 2     Clothing     57         2    114    Cash       5
# 7        Books     80         2    160    Cash       3
# 9        Books     80         2    160    Cash       4
# 10   Furniture     35         4    140    Gpay       4
# ..         ...    ...       ...    ...     ...     ...
# 977   Clothing     49         3    147    Cash       5
# 981    Fashion     81         2    162    Gpay       5
# 989   Sporting     19         7    133    Cash       1
# 994    Fashion     29         5    145    Cash       4
# 995  Groceries     31         4    124    Card       3
#
# [231 rows x 13 columns]

# %%
c = sales['Category'].drop_duplicates()
print(c)
# Out:
# 0     Groceries
# 1       Fashion
# 2      Clothing
# 3      Sporting
# 4         Books
# 10    Furniture
# Name: Category, dtype: object

# %%
sales.groupby(['City','Payment']).sum()['Total']
# Out:
# City     Payment
# Chicago  Card       18213
#          Cash       26164
#          Gpay       20838
# Dallas   Card       22851
#          Cash       22341
#          Gpay       25240
# NewYork  Card       23200
#          Cash       24138
#          Gpay       24803
# Name: Total, dtype: int64

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# 1      Fashion     35         5    175    Card       3
# 2     Clothing     57         2    114    Cash       5
# 3     Sporting     89         4    356    Gpay       1
# 4        Books     82         5    410    Cash       4
# ..         ...    ...       ...    ...     ...     ...
# 995  Groceries     31         4    124    Card       3
# 996  Groceries      3         5     15    Gpay       3
# 997   Clothing     71         5    355    Card       3
# 998   Clothing     89         7    623    Cash       5
# 999   Clothing     31         7    217    Gpay       3
#
# [1000 rows x 13 columns]

# %%
loc=sales.groupby('Location')

# %%
location=[x for x,y in loc]
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
sales.groupby('Location').sum()['Total']
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(location,sales.groupby('Location').sum()['Total'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(sales.groupby('Location').sum()['Total'],labels=location,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1969e69acd0>,
#   <matplotlib.patches.Wedge at 0x1969e69ba90>,
#   <matplotlib.patches.Wedge at 0x1969e6a5250>],
#  [Text(0.5080357843151302, 0.9756534435214743, 'Brookfield'),
#   Text(-1.0939745592878725, -0.11497679605427102, 'Park lane'),
#   Text(0.6072323961649048, -0.917207074246502, 'Water tower')],
#  [Text(0.2771104278082528, 0.5321746055571678, '34.7%'),
#   Text(-0.596713395975203, -0.06271461602960236, '33.9%'),
#   Text(0.33121767063540253, -0.5002947677708193, '31.4%')])

# %%
#Q3

# %%
sales.groupby(['Location']).count()
# Out:
#              Invoice ID  Date  Time  Gender  City  Member  Category  Price  \
# Location
# Brookfield          340   340   340     340   340     340       340    340
# Park lane           332   332   332     332   332     332       332    332
# Water tower         328   328   328     328   328     328       328    328
#
#              Quantity  Total  Payment  Rating
# Location
# Brookfield        340    340      340     340
# Park lane         332    332      332     332
# Water tower       328    328      328     328

# %%
sales.groupby(['Gender','Location']).count()['Invoice ID']
# Out:
# Gender  Location
# Female  Brookfield     179
#         Park lane      179
#         Water tower    143
# Male    Brookfield     161
#         Park lane      153
#         Water tower    185
# Name: Invoice ID, dtype: int64

# %%
lc=sales.groupby(['Gender','Location']).count()['Invoice ID']

# %%
lc
# Out:
# Gender  Location
# Female  Brookfield     179
#         Park lane      179
#         Water tower    143
# Male    Brookfield     161
#         Park lane      153
#         Water tower    185
# Name: Invoice ID, dtype: int64

# %%
uc=lc.unstack(level=0)
uc
# Out:
# Gender       Female  Male
# Location
# Brookfield      179   161
# Park lane       179   153
# Water tower     143   185

# %%
uc.plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
#q4 which days of month makes most sales
